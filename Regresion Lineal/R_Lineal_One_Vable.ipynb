# %%
import numpy as np
import matplotlib.pyplot as plt

import warnings
#suppress warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive

drive.mount('/content/drive')

# %pwd
# %cd "/content/drive/MyDrive/Colab Notebooks/IA/Regresion Lineal/"
# %pwd
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Colab Notebooks/IA/Regresion Lineal
# '/content/drive/MyDrive/Colab Notebooks/IA/Regresion Lineal'

# %%
data=np.loadtxt("datos.txt",delimiter=',',skiprows=0,usecols=[0,1],dtype='float')
print(data[:,1])
dataSize = data.shape
print(dataSize[0])
print(dataSize[1])
# Out:
# [17.592    9.1302  13.662   11.854    6.8233  11.886    4.3483  12.
#   6.5987   3.8166   3.2522  15.505    3.1551   7.2258   0.71618  3.5129
#   5.3048   0.56077  3.6518   5.3893   3.1386  21.767    4.263    5.1875
#   3.0825  22.638   13.501    7.0467  14.692   24.147   -1.22     5.9966
#  12.134    1.8495   6.5426   4.5623   4.1164   3.3928  10.117    5.4974
#   0.55657  3.9115   5.3854   2.4406   6.7318   1.0463   5.1337   1.844
#   8.0043   1.0179   6.7504   1.8396   4.2885   4.9981   1.4233  -1.4211
#   2.4756   4.6042   3.9624   5.4141   5.1694  -0.74279 17.929   12.054
#  17.054    4.8852   5.7442   7.7754   1.0173  20.992    6.6799   4.0259
#   1.2784   3.3411  -2.6807   0.29678  3.8845   5.7014   6.7526   2.0576
#   0.47953  0.20421  0.67861  7.5435   5.3436   4.2415   6.7981   0.92695
#   0.152    2.8214   1.8451   4.2959   7.2029   1.9869   0.14454  9.0551
#   0.61705]
# 97
# 2

# %% [markdown]
# **PLOT DATA**

# %%
plt.plot(data[:,0],data[:,1],'*')
plt.show()

# %%
Beta = np.zeros((2,1))
onesVector = np.ones((dataSize[0],))

X = np.column_stack((onesVector,data[:,0]))
y=np.zeros((dataSize[0],1))
y[:,0] = data[:,1]

alpha = 0.01
numIter = 500
m = dataSize[0]

# %%
temp1 = (np.reshape(X[:,0],(m,1)))
h_beta = np.dot(X,Beta)
temp3 = np. multiply(temp1,(np.subtract(h_beta,y)))
temp2 = np.sum(temp3)
temp4=temp2*(alpha/m)

# %%
def Gradiente(Beta,alpha,m,X,y,numIter,J):
  betaTemp = np.zeros((2,1))
  h_beta = np.zeros((m,1))
  Z = np.zeros((m,1))


  for i in range(numIter):
    for j in range(2):
      h_beta = np.dot(X,Beta)
      temp1 = (np.reshape(X[:,j],(m,1)))
      temp2 = np.sum(np. multiply(temp1,(np.subtract(h_beta,y))))
      betaTemp[j,0] = Beta[j,0] - (temp2*(alpha/m))

    Beta = betaTemp
    h_beta = np.dot(X,Beta)
    J[i]  = 0 #Implementar la función cost


  return (Beta, J)

# %%
alpha = 0.01
numIter = 5500
J = np.zeros(numIter,)
Beta = np.zeros((2,1))

Beta, J = Gradiente(Beta,alpha,m,X,y,numIter,J)

plt.plot(J,'*')
print(Beta)
# Out:
# [[-3.89560119]
#  [ 1.19301562]]

# %%
h_beta = np.dot(X,Beta)
plt.plot(data[:,0],data[:,1],'r*')
plt.plot(data[:,0],h_beta,'b*')
plt.show()

# %% [markdown]
# Parte 1
#
# 3. Please answer in English: (0.1 punto)
# 3.1 ¿Why is it necessary to normalize the X variables?
#
# R/= Because sometimes the data that we have are different, it say, the range or extension of the data are different among they, so, is necessary normalize the data and that way we will have the variables with a range define
#
# 3.2 ¿What can happen if the variable alpha (α) increases or decreases?
#
# R/= If the variable alpha increase could happen that the graph converges so fast to local minimum value and the necessity is to converge to global minimum
# If the variable alpha decrease could happen that the graph converges slow to the global minimum. If this happens will be necessary major iteration number
